# %%
import pandas as pd

# %%
data = pd.read_csv("world_alcohol.csv")

# %%
#Quantas bebidas diferentes ?

bebidas = list(data['Beverage Types'])
bebidas = set(bebidas)
len(bebidas)

#ou, em uma unica linha:
#len(set(list(data['Beverage Types'])))
# Out:
# 4

# %%
#Quais sao as bebidas diferente?
bebidas
# Out:
# {'Beer', 'Other', 'Spirits', 'Wine'}

# %%
#Quais paises bebem vinho ?
data.loc[data['Beverage Types'] == 'Wine']
# Out:
#       Year             WHO region  \
# 0     1986        Western Pacific
# 2     1985                 Africa
# 6     1987                 Africa
# 10    1987                 Africa
# 15    1987                 Africa
# 16    1984               Americas
# 20    1986        South-East Asia
# 26    1985                 Europe
# 31    1986        Western Pacific
# 34    1986                 Europe
# 43    1984        Western Pacific
# 49    1986                 Europe
# 52    1986  Eastern Mediterranean
# 55    1989               Americas
# 56    1987        Western Pacific
# 57    1989                 Europe
# 66    1987  Eastern Mediterranean
# 81    1985                 Europe
# 85    1985                 Africa
# 86    1986               Americas
# 87    1989  Eastern Mediterranean
# 89    1986  Eastern Mediterranean
# 90    1989                 Africa
# 96    1985                 Europe
# 97    1984        South-East Asia
# 98    1984                 Africa
# ...

# %%
#Quantos paises bebem cerveja?
(data['Beverage Types'].value_counts()).Beer
# Out:
# 816

# %%
#Qual pais bebe mais?
(data[ data['Display Value'] == data['Display Value'].max()]).Country.tolist()

#O que ele bebe?

#data.groupby(['Beverage Types'], sort=False)['Display Value'].max()

#idx = data.groupby(['Beverage Types'])['Display Value'].transform(max) == data['Display Value']
#(data[idx ])
# Out:
# ['Portugal']

# %%
#Quanto ele bebe?
data['Display Value'].max()
# Out:
# 13.5

# %%
#O que ele bebe?
(data[ data['Display Value'] == data['Display Value'].max()])['Beverage Types'].tolist()
# Out:
# ['Wine']

# %%
#De cada tipo de bebida, quais paises bebem mais
data[(data.groupby(['Beverage Types'])['Display Value'].transform(max) == data['Display Value'])]
# Out:
#       Year             WHO region                      Country Beverage Types  \
# 495   1986                 Europe                      Germany           Beer
# 530   1985                 Africa  United Republic of Tanzania          Other
# 691   1984                 Europe                     Portugal           Wine
# 1143  1984  Eastern Mediterranean         United Arab Emirates        Spirits
#
#       Display Value
# 495            8.68
# 530            7.80
# 691           13.50
# 1143          12.02
